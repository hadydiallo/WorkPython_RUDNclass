# %% [markdown]
# # Билет 2
# ## 1. Библиотека NumPy. Создание массивов. Стандартные типы данных библиотеки NumPy.
#
# ## 2. Вывести графики функции и её производной 𝑒𝑥 cos 𝑥. Найти min, max,  среднее значение на отрезке [0;1/2].
#
# ## 3. Прочитать файл данных. Построить зависимости. Построить гистограммы. comparison-ww-monthly-201902-202002.csv
#
# * Задания оформить в виде отчёта в Jupyter Notebook с использованием Markdown Все графики должны быть оформлены: добавить название графика, подписи осей, сетку, легенду (подписи кривых), сделать график удобным для чтения (подобрать масштаб отображения данных)

# %% [markdown]
# ----

# %% [markdown]
# - **RUDN UNiversity : НПМмд-01-19**
#
# - **Student : Мухамаду Хади Диалло**
#
# - **Teacher : Светлана Г.**

# %% [markdown]
# ----

# %% [markdown]
# ## 1_1 Библиотека NumPy

# %% [markdown]
# **NumPy** -это фундаментальный пакет для научных вычислений с использованием **Python**. Он содержит в себе помимо всего прочего :
#
# * мощный N-мерный массивный объект
#
# * сложные (вещательные) функции
#
# * инструменты для интеграции кода **C / C++** и **Fortran**
#
# * полезные возможности линейной алгебры, преобразования Фурье и случайных чисел
#
# Помимо очевидных научных применений, **NumPy** может также использоваться в качестве эффективного многомерного контейнера общих данных. Можно определить произвольные типы данных. Это позволяет **NumPy** легко и быстро интегрироваться с самыми разнообразными базами данных.

# %%
# getting library NumPy
import numpy as np

# %% [markdown]
# ## 1_2 Создание массивов

# %% [markdown]
# **NumPy** основным объектом является однородный многомерный массив. Это таблица элементов (обычно чисел), все одного типа, индексируемых кортежем неотрицательных целых чисел. В NumPy размеры называются осями. Существует 5 общих механизмов создания массивов:
#
# - Преобразование из других структур **Python (например, списки (list), кортежи (tuple))**
# - Внутренние объекты создания массива numpy (например, arange, ones, zeros,  и т. д.)
# - Чтение массивов с диска, как из стандартных, так и из пользовательских форматов
# - Создание массивов из необработанных байтов с помощью строк или буферов
# - Использование специальных библиотечных функций (например, random)

# %% [markdown]
# ####  Преобразование объектов Python array_like в массивы NumPy

# %%
x1 = np.array([2,3,1,0])
x2 = np.array([[1,2.0],[0,0],(1+1j,3.)]) # note mix of tuple and lists, and types
x3 = np.array([[ 1.+0.j, 2.+0.j], [ 0.+0.j, 0.+0.j], [ 1.+1.j, 3.+0.j]])
(x1,x2,x3)
# Out:
# (array([2, 3, 1, 0]), array([[1.+0.j, 2.+0.j],
#         [0.+0.j, 0.+0.j],
#         [1.+1.j, 3.+0.j]]), array([[1.+0.j, 2.+0.j],
#         [0.+0.j, 0.+0.j],
#         [1.+1.j, 3.+0.j]]))

# %% [markdown]
# #### Intrinsic NumPy Array Creation
# **zeros(shape)** будет создан массив, заполненный 0 значениями с заданной формой. Тип dtype по умолчанию-float64
#
# **arange()** будем создавать массивы с регулярно увеличивающимися значениями.
#
# **linspace()** будем создавать массивы с заданным количеством элементов, причем с равным интервалом между заданными начальными и конечными значениями.
#
# **indices()** будет создан набор массивов (сложенных в виде массива с одним более высоким размером), по одному на измерение, причем каждый из них представляет вариацию в этом измерении.

# %%
np.zeros((2, 3))
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
np.arange(2, 10, dtype=float)
# Out:
# array([2., 3., 4., 5., 6., 7., 8., 9.])

# %%
np.linspace(1., 4., 6)
# Out:
# array([1. , 1.6, 2.2, 2.8, 3.4, 4. ])

# %% [markdown]
# #### Чтение массивов из дисков,
# * стандартных двоичных форматов (jpg, png, etc)
# * распространенных форматах ASCII (Comma Separated Value files (CSV)
# * двоичный форматы

# %% [markdown]
# ## 1_3 Стандартные типы данных библиотеки NumPy

# %% [markdown]
# В **NumPy** существует 5 базовых числовых типов: булевы числа (тип bool: 0 - ложь и 1 - истина), целые числа (тип int), беззнаковые целые числа (тип uint), вещественные числа (числа с плавающей запятой, тип float) и комплексные числа (тип complex).
#
# **bool_**  Логический тип (истина или ложь), хранящийся в виде байта.
#
# **int_**  Целочисленный тип установленный по умолчанию (такой же, как C long, как правило это либо int64 либо int32).
#
# **float_** То же самое что и float64.
#
# **complex_** То же самое что и complex128
#
# Вообще, на самом деле это только верхушка айсберга. Все типы данных указаны в словаре *sctypeDict* в виде ключей, что бы посмотреть все доступные типы данных можно выполнить следующую команду:

# %%
np.sctypeDict
# Out:
# {'?': numpy.bool_,
#  0: numpy.bool_,
#  'byte': numpy.int8,
#  'b': numpy.int8,
#  1: numpy.int8,
#  'ubyte': numpy.uint8,
#  'B': numpy.uint8,
#  2: numpy.uint8,
#  'short': numpy.int16,
#  'h': numpy.int16,
#  3: numpy.int16,
#  'ushort': numpy.uint16,
#  'H': numpy.uint16,
#  4: numpy.uint16,
#  'i': numpy.int32,
#  5: numpy.int32,
#  'uint': numpy.uint32,
#  'I': numpy.uint32,
#  6: numpy.uint32,
#  'intp': numpy.int64,
#  'p': numpy.int64,
#  9: numpy.int64,
#  'uintp': numpy.uint64,
#  'P': numpy.uint64,
#  10: numpy.uint64,
#  'long': numpy.int32,
#  'l': numpy.int32,
#  7: numpy.int32,
#  'L': numpy.uint32,
#  8: numpy.uint32,
#  'longlong': numpy.int64,
#  'q': numpy.int64,
#  'ulonglong': numpy.uint64,
#  'Q': numpy.uint64,
#  'half': numpy.float16,
#  'e': numpy.float16,
#  23: numpy.float16,
#  'f': numpy.float32,
#  11: numpy.float32,
#  'double': numpy.float64,
#  'd': numpy.float64,
#  12: numpy.float64,
#  'longdouble': numpy.float64,
#  'g': numpy.float64,
# ...

# %% [markdown]
# ## 2. Вывести графики функции и её производной $e^x \cos{x}$. Найти min, max,  среднее значение на отрезке $[0;\pi/2]$.
#
# $f(x)=e^x \cos{x}$ , $x\in [0;\pi/2] $
#
# $f'(x)=e^x (\cos{x}-\sin{x})$
#
#
# #### графики функции и её производной

# %%
## pip install ggplot

# %%
from math import pi, cos, sin, exp
import matplotlib.pyplot as plt
#import ggplot ## make the graphic more beautiful

x=np.linspace(0,pi/2,10)
def f(x):
    return exp(x)*cos(x)
def ff(x) :
    return exp(x)*(cos(x)-sin(x))
f_x=np.zeros(len(x))
ff_x=np.zeros(len(x))
for i in range(len(x)):
    f_x[i]=f(x[i])
    ff_x[i]=ff(x[i])

fig, ax = plt.subplots()
ax.plot(x,f_x, label='f(x)')
ax.plot(x,ff_x, label="f'(x)")
ax.set_xlabel("x")
ax.set_ylabel("functions")
ax.set_title("функции и её производной f(x)")
ax.legend()
#fig.show()

# %% [markdown]
# #### Найти min, max, среднее значение на отрезке  [0;𝜋/2]

# %%
Min=np.round(np.min(f_x),5)
Max=np.round(np.max(f_x),5)
Mean=np.round(np.mean(f_x),5)
print("min= ",Min," Max= ",Max," среднее значение= ",Mean)
# Out:
# min=  0.0  Max=  1.53974  среднее значение=  1.13318

# %% [markdown]
# ## 3. Прочитать файл данных. Построить зависимости. Построить гистограммы. comparison-ww-monthly-201902-202002.csv

# %% [markdown]
# #### Прочитать файл данных

# %%
#help(np.genfromtxt)

# %%
data_path = "comparison-ww-monthly-201902-202002.csv"
types = ['a25','f4', 'f4', 'f4']
data = np.genfromtxt(data_path, dtype=types, delimiter=',', names=True)
data
# Out:
# array([(b'2019-02', 47.96, 48.21, 3.83), (b'2019-03', 48.98, 47.04, 3.98),
#        (b'2019-04', 48.32, 47.79, 3.9 ), (b'2019-05', 47.9 , 48.27, 3.84),
#        (b'2019-06', 50.71, 45.53, 3.76), (b'2019-07', 51.11, 45.18, 3.71),
#        (b'2019-08', 51.65, 44.6 , 3.75), (b'2019-09', 51.78, 44.57, 3.65),
#        (b'2019-10', 52.48, 44.59, 2.93), (b'2019-11', 52.03, 45.17, 2.8 ),
#        (b'2019-12', 53.29, 43.99, 2.72), (b'2020-01', 52.02, 45.29, 2.7 ),
#        (b'2020-02', 51.69, 45.66, 2.65)],
#       dtype=[('Date', 'S25'), ('Mobile', '<f4'), ('Desktop', '<f4'), ('Tablet', '<f4')])

# %% [markdown]
# #### Построить зависимости.

# %%
# Plot the data
fig, ax = plt.subplots()
ax.plot( data['Date'], data['Mobile'], label='Mobile')
ax.plot( data['Date'], data['Desktop'], label='Desktop')
ax.plot( data['Date'], data['Tablet'], label='Tablet')
ax.set_xlabel("Date")
ax.set_ylabel("Frequency")
ax.set_title("Comparaison of using tools from feb 2019 to feb 2020")
ax.legend()
fig.show()
def comp_graph(a) :
    fig, ax = plt.subplots()
    ax.plot(data['Date'],data[a], 'b', label=a)
    ax.set_xlabel("Date")
    ax.set_ylabel("Frequency")
    ax.set_title("Using "+a+" from feb 2019 to feb 2020")
    ax.legend()
    fig.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   # Remove the CWD from sys.path while we load stuff.

# %%
comp_graph('Mobile')
comp_graph('Desktop')
comp_graph('Tablet')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %% [markdown]
# #### Построить гистограммы.

# %%
def histogramm(a) :
    plt.style.use('ggplot')
    plt.hist(data[a], bins='auto', color='#0504aa',
                                alpha=0.7, rwidth=0.85, density=True)
    plt.grid(axis='y', alpha=0.95)
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.title(a+ ' using distribition from feb 2019 to feb 2020')
    plt.show()
histogramm('Mobile')
histogramm('Desktop')
histogramm('Tablet')

# %%
#import seaborn
#seaborn.pairplot(data, vars=['Mobile', 'Desktop', 'Tablet'],
#                 kind='reg') # ,hue='Month'
